# %% [markdown]
# ### Strings
# Strings in python are surrounded by either single quotation marks, or double quotation marks.

# %% [markdown]
# ### Quotes Inside Quotes
# You can use quotes inside a string, as long as they don't match the quotes surrounding the string:

# %%
print("It's alright")
print("He is called 'Johnny'")
print('He is called "Johnny"')
# Out:
# It's alright
# He is called 'Johnny'
# He is called "Johnny"

# %%
a = "Hello world"
print(a[2])
# Out:
# l

# %% [markdown]
# Remove Whitespace
#
# Whitespace is the space before and/or after the actual text, and very often you want to remove this space.

# %%
# remove white space using strip()
print(a.strip())
# Out:
# Hello world

# %%
a = "Hello, World!"
print(a.replace("H", "J"))
# Out:
# Jello, World!

# %%
a = "Hello, World!"
print(a.split(",")) # returns ['Hello', ' World!']
# Out:
# ['Hello', ' World!']

# %%
a = "Hello"
b = "World"
c = a + b
print(c)
# Out:
# HelloWorld

# %%
a = "Hello"
b = "World"
c = a + " " + b
print(c)
# Out:
# Hello World

# %% [markdown]
# # String Methods

# %% [markdown]
# ### String Case & Formatting
# | Method              | Description                                     | Example                                               |
# | :------------------ | :---------------------------------------------- | :---------------------------------------------------- |
# | `upper()`           | Converts all characters to uppercase            | `"hello".upper()` → `'HELLO'`                         |
# | `lower()`           | Converts all characters to lowercase            | `"HELLO".lower()` → `'hello'`                         |
# | `title()`           | Converts first letter of each word to uppercase | `"hello world".title()` → `'Hello World'`             |
# | `capitalize()`      | Capitalizes only the first character            | `"python".capitalize()` → `'Python'`                  |
# | `strip()`           | Removes whitespace from both ends               | `"  hi  ".strip()` → `'hi'`                           |
# | `replace(old, new)` | Replaces a substring                            | `"good day".replace("good", "great")` → `'great
#
# ### Searching & Checking
# | Method            | Description                                 | Example                              |
# | :---------------- | :------------------------------------------ | :----------------------------------- |
# | `find(sub)`       | Returns index of first occurrence (or `-1`) | `"apple".find("p")` → `1`            |
# | `count(sub)`      | Counts occurrences of substring             | `"banana".count("a")` → `3`          |
# | `startswith(sub)` | Checks if string starts with given text     | `"python".startswith("py")` → `True` |
# | `endswith(sub)`   | Checks if string ends with given text       | `"python".endswith("on")` → `True`   |
# | `in` *(operator)* | Checks membership                           | `"a" in "banana"` → `True`
# ### Splitting & Joining
# | Method           | Description                                           | Example                                       |
# | :--------------- | :---------------------------------------------------- | :-------------------------------------------- |
# | `split()`        | Splits string into list (by space or given delimiter) | `"a,b,c".split(",")` → `['a', 'b', 'c']`      |
# | `join(iterable)` | Joins list elements into a string                     | `" ".join(['I', 'am', 'GPT'])` → `'I am GPT'`
#  ### Validation / Checking Type
# | Method      | Description                        | Example                       |
# | :---------- | :--------------------------------- | :---------------------------- |
# | `isalpha()` | True if all characters are letters | `"abc".isalpha()` → `True`    |
# | `isdigit()` | True if all are digits             | `"123".isdigit()` → `True`    |
# | `isalnum()` | True if alphanumeric               | `"abc123".isalnum()` → `True` |
# | `isspace()` | True if all are spaces             | `"   ".isspace()` → `True`    |
# | `islower()` | True if all lowercase              | `"hello".islower()` → `True`  |
# | `isupper()` | True if all uppercase              | `"HELLO".isupper()` → `Tue`  |
# |
#     |
# day'` |

# %% [markdown]
# ### Basic Operations
# 1. Length of a String
# 2. Check for Same
# 3. Search a Character
# 4. Insert a Character
# 5. Remove a Character
# 6. Remove all occurrences
# 7. Concatenating Two Strings
# 8. Reverse a string
# 9. Generate all Substrings

# %%
# Length of the String 
a = "Vaibhaav"
print(len(a))
# Out:
# 8

# %%
def count_len(a):
    cnt = 0
    for c in a:
        cnt = cnt+1
    return cnt 
a = "Vaibhaav"
count_len(a)
# Out:
# 8

# %%
# Check for same
a = "abc"
b = "nbc"
def check_str(a,b):
    return a==b

check_str(a,b)
# Out:
# False

# %%
a = "XYZ"
b = "XYZ"
def check_str(a,b):
    if len(a)!=len(b):
        return False
    else:
        for i in range(len(a)):
            if a[i]!=b[i]:
                return False 
    return True
                
check_str(a,b)
# Out:
# True

# %%
# Program to Search a Character in a String
ch = "p"
s = "vaibhav"
def check_str(s, ch):
    n = len(s)
    for i in range(n):
        if s[i]==ch:
            return True 
        else:
            return False 
check_str(s, ch)
# Out:
# False

# %%
def find_character_index(s, ch):
    idx = s.find(ch)
    return idx 

s = "vaibhav"
ch = 'v'

index = find_character_index(s, ch)
print(index)
# Out:
# 0

# %% [raw]
# # Insert a character in String at a Given Position
#
# Input: s = "Geeks", c = 'A', pos = 3
# Output: GeeAks
#
# Input: s = "HelloWorld", c = '!', pos = 5
# Output: Hello!World

# %%
s = "vaibhav"
c = 'n'
pos = 3

def insert_char(s, c, pos):
    n = len(s):
    for i in range(n):
        if i == pos:

# %%
# Python program to insert a character at 
# specific position using custom method

def insertChar(s, c, pos):
  
    # Insert character at specified position
    return s[:pos] + c + s[pos:]

s = "vaibhav"
print(insertChar(s, 'k', 3))
# Out:
# vaikbhav

# %%
# Python program to insert a character at 
# specific position using custom method

def insertChar(s, c, pos):
    res = ""
    for i in range(len(s)):
      
        # Insert the character at 
        # the given position
        if i == pos: 
            res += c
      
        # Insert the original characters
        res += s[i]
  
    # If the given pos is beyond the length,  
    # append the character at the end
    if pos >= len(s): 
        res += c
      
    return res

s = "Geeks"
print(insertChar(s, 'A', 3))
# Out:
# GeeAks
